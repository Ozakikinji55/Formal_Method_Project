# %% [markdown]
# # Notebook Overview
#
# This notebook is used to translate the multi-labeled scenario text into training, testing and validation datasets for machine learning. This division would normally correspond to a 80/10/10 split, respectively.
#
# While training the BERT-based model using the HuggingFace API can be performed on word-token sequences, the evaluation for the BERT-based model assumes complete scenario texts. Therefore, we split the dataset using a random selection of scenarios and not using a random selection of sentences, which could provide more sample diversity in training. The CRF-based model requires sentence-token sequences, thus, each scenario's token sequence in the dataset is organized by sentence. The CRF-based model also requires part-of-speech (POS) as input to feature development, in addition to tokenized words.

# %%
import json

# load the unprocessed, labeled scenarios
scenarios = json.load(open('scenarios-labeled.json'))
scenarios[0]
# Out:
# {'text': "From this screen, I like to search for anything from recipes, to home decor, to people, etc., just depending on my mood. To get to this screen all I had to do was tap on the little magnifying glass next to the image of the home icon, and this is where you would search for whatever you like, kind of like how it works with google, but more customized to your preferences and trends. To find whatever I'm looking for, I click on the search bar to type a word or phrase. I try to keep it brief. For example, if I'm looking for a pasta recipe for dinner, I'll type pasta dinner recipe, then select the phrase that matches what I'm looking for. I then rummage through the available pins and decide which one I like the most before saving the pin to the board that most closely matches the kind of query I made. ",
#  'scenario_id': 'MAS-G-0001',
#  'app_url': 'https://apps.apple.com/us/app/pinterest/id429047995',
#  'labels': [[53, 60, 'SIM'],
#   [65, 75, 'SIM'],
#   [80, 86, 'SIM'],
#   [359, 370, 'SIM'],
#   [375, 381, 'SIM'],
#   [432, 442, 'SIM'],
#   [453, 457, 'SIM'],
#   [461, 467, 'SIM'],
#   [533, 539, 'SIM'],
#   [575, 581, 'SIM']]}

# %%
scenarios.extend([s for s in json.load(open('scenarios-risked.json')) if len(s['labels']) > 0])

# %%
# remove overlapping scenarios, retaining longest label

def find_longest_overlap(label1, label2):
    span1 = set(range(label1[0], label1[1]))
    span2 = set(range(label2[0], label2[1]))

    if len(span1.intersection(span2)) == 0:
        return 0
    elif len(span1) > len(span2):
        return -1
    else:
        return 1

# find the label indices that are shortest and overlapping
deleted_labels = []
for scenario in scenarios:
    labels = scenario['labels']
    overlaps = set()
    for i in range(len(labels)):
        for j in range(i + 1, len(labels)):
            overlap = find_longest_overlap(labels[i], labels[j])
            if overlap == 0:
                continue
            elif overlap < 0:
                overlaps.add(j)
            else:
                overlaps.add(i)
    
    # delete short overlapping labels from the list
    for i in sorted(overlaps, reverse=True):
        deleted_labels.append(labels[i][2])
        del labels[i]
        
print('Deleted %i overlapping labels' % len(deleted_labels))
# Out:
# Deleted 401 overlapping labels

# %%
! pip install "spacy==3.7.5"
! pip install "nltk==3.8.1"
! python -m spacy download en_core_web_sm
# Out:
# Collecting spacy==3.7.5
#   Using cached spacy-3.7.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy==3.7.5)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy==3.7.5)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy==3.7.5)
#   Using cached murmurhash-1.0.15-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy==3.7.5)
#   Using cached cymem-2.0.13-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy==3.7.5)
#   Using cached preshed-3.0.13-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy==3.7.5)
#   Using cached thinc-8.2.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy==3.7.5)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy==3.7.5)
#   Using cached srsly-2.5.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy==3.7.5)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy==3.7.5)
#   Using cached weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy==3.7.5)
#   Using cached typer-0.23.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy==3.7.5) (4.67.3)
# Collecting requests<3.0.0,>=2.13.0 (from spacy==3.7.5)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy==3.7.5)
#   Downloading pydantic-2.13.2-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy==3.7.5) (3.1.6)
# Requirement already satisfied: setuptools in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy==3.7.5) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy==3.7.5) (26.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy==3.7.5)
#   Using cached langcodes-3.5.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: numpy>=1.19.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy==3.7.5) (2.0.2)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5)
#   Downloading pydantic_core-2.46.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5) (4.14.1)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy==3.7.5)
#   Using cached charset_normalizer-3.4.7-cp39-cp39-macosx_10_9_universal2.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy==3.7.5)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy==3.7.5)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy==3.7.5)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy==3.7.5)
#   Using cached blis-0.7.11-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy==3.7.5)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy==3.7.5)
#   Using cached numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.7.5) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy==3.7.5)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0.0,>=0.3.0->spacy==3.7.5)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy==3.7.5)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from weasel<0.5.0,>=0.1.0->spacy==3.7.5)
#   Using cached typer_slim-0.23.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy==3.7.5)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy==3.7.5)
#   Using cached smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy==3.7.5)
#   Using cached wrapt-2.1.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy==3.7.5)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy==3.7.5) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy==3.7.5)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from jinja2->spacy==3.7.5) (3.0.3)
# Using cached spacy-3.7.5-cp39-cp39-macosx_11_0_arm64.whl (6.6 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.13-cp39-cp39-macosx_11_0_arm64.whl (43 kB)
# Using cached langcodes-3.5.1-py3-none-any.whl (183 kB)
# Using cached murmurhash-1.0.15-cp39-cp39-macosx_11_0_arm64.whl (27 kB)
# Using cached preshed-3.0.13-cp39-cp39-macosx_11_0_arm64.whl (139 kB)
# Downloading pydantic-2.13.2-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.2-cp39-cp39-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.1 MB/s  0:00:00
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.7-cp39-cp39-macosx_10_9_universal2.whl (299 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.5.3-cp39-cp39-macosx_11_0_arm64.whl (658 kB)
# Using cached thinc-8.2.5-cp39-cp39-macosx_11_0_arm64.whl (780 kB)
# Using cached blis-0.7.11-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
# Using cached typer-0.23.2-py3-none-any.whl (56 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.3-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached smart_open-7.5.0-py3-none-any.whl (63 kB)
# Using cached typer_slim-0.23.2-py3-none-any.whl (3.4 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached wrapt-2.1.2-cp39-cp39-macosx_11_0_arm64.whl (61 kB)
# Installing collected packages: wrapt, wasabi, urllib3, typing-inspection, spacy-loggers, spacy-legacy, shellingham, pydantic-core, numpy, murmurhash, mdurl, langcodes, idna, cymem, cloudpathlib, charset_normalizer, certifi, catalogue, annotated-types, annotated-doc, srsly, smart-open, requests, pydantic, preshed, markdown-it-py, blis, rich, confection, typer, thinc, typer-slim, weasel, spacy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [spacy]m33/34 [spacy]]s]]
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 certifi-2026.2.25 charset_normalizer-3.4.7 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 idna-3.11 langcodes-3.5.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.15 numpy-1.26.4 preshed-3.0.13 pydantic-2.13.2 pydantic-core-2.46.2 requests-2.32.5 rich-15.0.0 shellingham-1.5.4 smart-open-7.5.0 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.2.5 typer-0.23.2 typer-slim-0.23.2 typing-inspection-0.4.2 urllib3-2.6.3 wasabi-1.1.3 weasel-0.4.3 wrapt-2.1.2
# Collecting nltk==3.8.1
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from nltk==3.8.1) (8.1.8)
# Requirement already satisfied: joblib in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from nltk==3.8.1) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from nltk==3.8.1) (2026.1.15)
# Requirement already satisfied: tqdm in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from nltk==3.8.1) (4.67.3)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.0 MB/s  0:00:0036m-:--:--
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.2
#     Uninstalling nltk-3.9.2:
#       Successfully uninstalled nltk-3.9.2
# Successfully installed nltk-3.8.1
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 26.3 MB/s  0:00:00 eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.13)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.23.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.13.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.6)
# Requirement already satisfied: setuptools in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (26.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.46.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2026.2.25)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.0.4)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.23.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.5.0)
# Requirement already satisfied: wrapt in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/Angela/lib/python3.9/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy, nltk

# load the spacey nlp processor for pos-tagging, sentence segmentation
nlp = spacy.load("en_core_web_sm")

def get_label(token, labels):
    start = token.idx
    end = token.idx + len(token.text)
    for label in labels:
        if label[0] <= start and end <= label[1]:
            return label[2]
    return 'O'
    
tokenized = []
for scenario in scenarios:
    labels = scenario['labels']
    
    # parse scenario text and tokenize using the BIO-format
    doc = nlp(scenario['text'])
    tokenized.append(scenario.copy())
    tokenized[-1]['tokens'] = []
    last_label = 'O'
    sent = []
    for token in doc:
        if token.is_sent_start:
            sent = []
            tokenized[-1]['tokens'].append(sent)
                      
        new_label = get_label(token, labels)
        if new_label != 'O':
            if new_label != last_label:
                last_label = new_label
                new_label = 'B-' + new_label
            else:
                new_label = 'I-' + new_label
        else:
            last_label = new_label

        sent.append([token.text, token.tag_, new_label])

# %%
print('Converted %i scenarios and %i sentences.' % (len(tokenized), sum([len(d['tokens']) for d in tokenized])))
# Out:
# Converted 498 scenarios and 4034 sentences.

# %%
import random
from collections import Counter

def report_frequencies(dataset):
    counter = {dataset_name:Counter() for dataset_name in dataset.keys()}

    # report frequences per dataset
    total_sent = 0
    total_token = 0
    total_counter = Counter()
    for dataset_name, data in dataset.items():
        for scenario in data:
            for tokens in scenario['tokens']:
                total_sent += 1
                for word, pos, tag in tokens:
                    counter[dataset_name][tag] += 1
                    total_counter[tag] += 1
                    total_token += 1

    for dataset_name, data in dataset.items():
        token_count = sum([c for c in counter[dataset_name].values()])
        print('\nDataset %s: %i scenarios (%0.3f), %i tokens (%0.3f):' % (
            dataset_name.upper(),
            len(data),
            len(data) / total_sent,
            token_count,
            token_count / total_token
        ))
        labels = sorted(list(counter[dataset_name].keys()))
        for label in labels:
            print('%s: %i (%0.3f)' % (
                label.rjust(10), 
                counter[dataset_name][label], 
                counter[dataset_name][label] / 
                total_counter[label]
            ))

dataset = {}
if True:
    total_scenarios = len(tokenized)
    index1 = int(total_scenarios * 0.80)
    index2 = int(index1 + (total_scenarios * 0.10))

    # randomize the scenarios by scenario_id
    shuffled = tokenized.copy()
    random.shuffle(shuffled)
    
    # divide randomized sentences into train, test, validation splits
    dataset = {
        'train': shuffled[0:index1],
        'test': shuffled[index1:index2],
        'validation': shuffled[index2:],
    }
else:
    split_ids = json.load(open('deployed_split_ids.json'))
    dataset = {'train': [], 'test': [], 'validation': []}
    for scenario in tokenized:
        if scenario['scenario_id'] in split_ids['train_ids']:
            dataset['train'].append(scenario)
        elif scenario['scenario_id'] in split_ids['test_ids']:
            dataset['test'].append(scenario)
        elif scenario['scenario_id'] in split_ids['validation_ids']:
            dataset['validation'].append(scenario)

report_frequencies(dataset)
# Out:
# Dataset TRAIN: 398 scenarios (0.099), 73632 tokens (0.802):
#      B-COM: 364 (0.841)
#      B-QUE: 525 (0.785)
#      B-SIM: 5247 (0.807)
#      I-COM: 1781 (0.857)
#      I-QUE: 3002 (0.766)
#      I-SIM: 872 (0.803)
#          O: 61841 (0.802)
#
# Dataset TEST: 49 scenarios (0.012), 8877 tokens (0.097):
#      B-COM: 26 (0.060)
#      B-QUE: 76 (0.114)
#      B-SIM: 613 (0.094)
#      I-COM: 100 (0.048)
#      I-QUE: 475 (0.121)
#      I-SIM: 98 (0.090)
#          O: 7489 (0.097)
#
# Dataset VALIDATION: 51 scenarios (0.013), 9336 tokens (0.102):
#      B-COM: 43 (0.099)
#      B-QUE: 68 (0.102)
#      B-SIM: 644 (0.099)
#      I-COM: 196 (0.094)
#      I-QUE: 443 (0.113)
#      I-SIM: 116 (0.107)
#          O: 7826 (0.101)

# %%
json.dump(dataset, open('../models/scenarios-training-N.json', 'w'))
